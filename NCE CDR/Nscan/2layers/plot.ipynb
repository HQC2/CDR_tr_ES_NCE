# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from joblib import Parallel, delayed

# %%
df = pd.read_csv('deltas_and_std_k1to4.csv')

deltas = df['delta'].tolist()
std = df['std'].tolist()

# %%
ES = [0.13137632603137828 for _ in range(1000)]
tr = [0.18714338562709099 for _ in range(1000)]
x = np.arange(1, 1001)

plt.figure(figsize=(12, 8))
plt.plot(x, deltas, linestyle='-', color='b', label='NCE CDR')
plt.plot(x, ES, linestyle='-', color='r', label='ES CDR')
plt.plot(x, tr, linestyle='-', color='g', label='traditional CDR')
#plt.plot(x, exact, label="exact value")
#plt.plot(x_linear, noisy, label="noisy value")

plt.ylim(0, 0.2)

#plt.title('Averages', fontsize=16)
plt.xlabel(r'$N_s$', fontsize=28)
plt.ylabel(r'$E_{\mathrm{exact}} - E_{\mathrm{mitigated}}\ [\mathrm{Ha}]$', fontsize=28)
plt.legend(fontsize=20)
plt.grid(alpha=0.5)
plt.xticks(fontsize=24) 
plt.yticks(fontsize=24)

plt.tight_layout()
#plt.savefig("avg.png")
