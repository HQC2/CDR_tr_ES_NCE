# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from joblib import Parallel, delayed

# %%
df_tr = pd.read_csv('tr_kscan.csv')
deltas_tr = df_tr['delta'].tolist()
std_tr = df_tr['std'].tolist()

df_ES = pd.read_csv('ES_kscan.csv')
deltas_ES = df_ES['delta'].tolist()
std_ES = df_ES['std'].tolist()

df_NCE = pd.read_csv('NCE_kscan.csv')
deltas_NCE = df_NCE['delta'].tolist()
std_NCE = df_NCE['std'].tolist()

# %%
x_linear = np.arange(1, 18) 
x_others = np.arange(1, 18) 
x_other = np.arange(1, 18)
plt.figure(figsize=(10, 6))
plt.plot(x_linear, deltas_NCE, label='NCE', linestyle='-', marker='o', color='b')
#plt.plot(x_others, delta_linear, label='traditional Linear biased', linestyle='-', color='r', marker = 'o')
plt.plot(x_others, deltas_tr, label='traditional Quadratic biased', linestyle='-', color='r', marker = 'o')
plt.plot(x_other, deltas_ES, label='ES Quadratic', linestyle='-', marker='o', color='g')
plt.ylim(0, 0.3)

#plt.title('Absolute Energy Error', fontsize=16)
plt.xlabel(r'$k$', fontsize=16)
plt.ylabel(r'$E_{\mathrm{exact}} - E_{\mathrm{mitigated}}\ [\mathrm{Ha}]$', fontsize=16)
plt.legend(fontsize=16)
plt.grid(alpha=0.5)
plt.xticks(range(1, 18, 2),fontsize=14) 
plt.yticks(fontsize=14)
#plt.tight_layout()
plt.show()
